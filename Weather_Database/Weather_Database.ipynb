# %%
#Import the dependencies
import pandas as pd
import numpy as np 
import gmaps
import matplotlib.pyplot as plt
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
from datetime import datetime
from config import weather_api_key
from config import g_key
#Import the request lirary
import requests
# Import time module
import time
import ipywidgets as widgets

# %%
# Create a set of random latitude and longitude combinations
#where lats= latitudes & lngs = longitudes 
lats = np.random.uniform(low = -90.000 ,high= 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats,lngs)
#there will be 2,000 tuples of paired latitudes and longitudes, 
#where each latitude and longitude in a tuple can be accessed by the index of 0 and 1, respectively.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = (citipy.nearest_city(coordinate[0], coordinate[1]).city_name)
        
     # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 798

# %%
#Declera an empty list
city_data = []
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#Creating counters 
record_count = 1
set_count = 1

# %%
#For the previous error we can use the enumerate() method to iterate through the list 
# the sintaxis is the foollowing: for i, item in enumerate(list):

# Run an API request for each of the cities.
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_des = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_weather_des,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | camacha
# Processing Record 2 of Set 1 | esperance
# Processing Record 3 of Set 1 | zhigansk
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | itarema
# Processing Record 6 of Set 1 | mayo
# Processing Record 7 of Set 1 | isangel
# Processing Record 8 of Set 1 | saldanha
# Processing Record 9 of Set 1 | sobolevo
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | wurzen
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | katsuura
# Processing Record 20 of Set 1 | domoni
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | hualmay
# Processing Record 24 of Set 1 | hasaki
# Processing Record 25 of Set 1 | cuamba
# Processing Record 26 of Set 1 | port macquarie
# Processing Record 27 of Set 1 | kokopo
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | ashqelon
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | pangkalanbuun
# Processing Record 33 of Set 1 | ballina
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | lubango
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | belmonte
# Processing Record 38 of Set 1 | stijena
# Processing Record 39 of Set 1 | vila franca do campo
# Processing Record 40 of Set 1 | san cristobal
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 1 | gimli
# Processing Record 46 of Set 1 | itupiranga
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | brandon
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | mao
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | litovko
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | hof
# Processing Record 8 of Set 2 | mapiri
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | pangody
# Processing Record 11 of Set 2 | huarmey
# Processing Record 12 of Set 2 | haines junction
# Processing Record 13 of Set 2 | haapiti
# Processing Record 14 of Set 2 | port lincoln
# Processing Record 15 of Set 2 | stekolnyy
# City not found. Skipping...
# Processing Record 16 of Set 2 | zigong
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | madera
# Processing Record 19 of Set 2 | salalah
# Processing Record 20 of Set 2 | margate
# Processing Record 21 of Set 2 | ilulissat
# Processing Record 22 of Set 2 | tandil
# Processing Record 23 of Set 2 | guerrero negro
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | makakilo city
# Processing Record 27 of Set 2 | brigham city
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | port-cartier
# Processing Record 32 of Set 2 | krasnoselkup
# Processing Record 33 of Set 2 | paracuru
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | flinders
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | ahipara
# Processing Record 40 of Set 2 | tautira
# Processing Record 41 of Set 2 | itaituba
# Processing Record 42 of Set 2 | port hardy
# Processing Record 43 of Set 2 | aitape
# Processing Record 44 of Set 2 | severnoye
# Processing Record 45 of Set 2 | gigant
# Processing Record 46 of Set 2 | yialos
# City not found. Skipping...
# Processing Record 47 of Set 2 | oberndorf
# Processing Record 48 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 2 | mareeba
# Processing Record 50 of Set 2 | oktyabrskiy
# Processing Record 1 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 3 | busselton
# Processing Record 3 of Set 3 | salinas
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | labuan
# Processing Record 6 of Set 3 | alofi
# Processing Record 7 of Set 3 | antalaha
# Processing Record 8 of Set 3 | pamekasan
# Processing Record 9 of Set 3 | rawson
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | labuhan
# Processing Record 12 of Set 3 | vaitape
# Processing Record 13 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | flin flon
# Processing Record 16 of Set 3 | safford
# Processing Record 17 of Set 3 | nouakchott
# Processing Record 18 of Set 3 | tuatapere
# Processing Record 19 of Set 3 | hofn
# Processing Record 20 of Set 3 | souillac
# Processing Record 21 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 3 | lasa
# Processing Record 23 of Set 3 | tsaratanana
# Processing Record 24 of Set 3 | sirsa
# Processing Record 25 of Set 3 | padang
# Processing Record 26 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 3 | madang
# Processing Record 28 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 29 of Set 3 | victoria
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | walvis bay
# Processing Record 32 of Set 3 | thyolo
# Processing Record 33 of Set 3 | kuching
# Processing Record 34 of Set 3 | liwale
# Processing Record 35 of Set 3 | lagoa
# Processing Record 36 of Set 3 | dhidhdhoo
# Processing Record 37 of Set 3 | ayolas
# Processing Record 38 of Set 3 | vila
# Processing Record 39 of Set 3 | cayenne
# Processing Record 40 of Set 3 | tres arroyos
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | hit
# Processing Record 43 of Set 3 | dikson
# Processing Record 44 of Set 3 | bafoulabe
# Processing Record 45 of Set 3 | matay
# Processing Record 46 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 3 | ancud
# Processing Record 48 of Set 3 | cabo san lucas
# Processing Record 49 of Set 3 | clyde river
# Processing Record 50 of Set 3 | benjamin constant
# Processing Record 1 of Set 4 | tecoanapa
# Processing Record 2 of Set 4 | upernavik
# Processing Record 3 of Set 4 | aykhal
# Processing Record 4 of Set 4 | revelstoke
# Processing Record 5 of Set 4 | borovoy
# Processing Record 6 of Set 4 | port blair
# Processing Record 7 of Set 4 | bentiu
# Processing Record 8 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 4 | sorland
# Processing Record 10 of Set 4 | nefteyugansk
# Processing Record 11 of Set 4 | ishigaki
# Processing Record 12 of Set 4 | libertador general san martin
# Processing Record 13 of Set 4 | khani
# Processing Record 14 of Set 4 | port alfred
# Processing Record 15 of Set 4 | nikolskoye
# Processing Record 16 of Set 4 | nishihara
# Processing Record 17 of Set 4 | cherskiy
# Processing Record 18 of Set 4 | anori
# Processing Record 19 of Set 4 | ittiri
# Processing Record 20 of Set 4 | nelson bay
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | bandarbeyla
# Processing Record 23 of Set 4 | urucara
# Processing Record 24 of Set 4 | pimentel
# Processing Record 25 of Set 4 | san lorenzo
# Processing Record 26 of Set 4 | vierzon
# Processing Record 27 of Set 4 | lebu
# Processing Record 28 of Set 4 | kisangani
# Processing Record 29 of Set 4 | viedma
# Processing Record 30 of Set 4 | stornoway
# Processing Record 31 of Set 4 | fare
# Processing Record 32 of Set 4 | qeshm
# Processing Record 33 of Set 4 | portland
# Processing Record 34 of Set 4 | zhezkazgan
# Processing Record 35 of Set 4 | west lafayette
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | bom jardim
# Processing Record 38 of Set 4 | charters towers
# Processing Record 39 of Set 4 | balad
# Processing Record 40 of Set 4 | hefei
# Processing Record 41 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 4 | khandagayty
# Processing Record 43 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 4 | lakeway
# Processing Record 45 of Set 4 | myingyan
# Processing Record 46 of Set 4 | novovarshavka
# Processing Record 47 of Set 4 | majene
# Processing Record 48 of Set 4 | chapais
# Processing Record 49 of Set 4 | bokovskaya
# Processing Record 50 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 5 | bethel
# Processing Record 2 of Set 5 | songjianghe
# Processing Record 3 of Set 5 | bredasdorp
# Processing Record 4 of Set 5 | nabire
# Processing Record 5 of Set 5 | tiguib
# Processing Record 6 of Set 5 | linhares
# Processing Record 7 of Set 5 | thompson
# Processing Record 8 of Set 5 | coihaique
# Processing Record 9 of Set 5 | hauterive
# Processing Record 10 of Set 5 | alta floresta
# Processing Record 11 of Set 5 | aksu
# Processing Record 12 of Set 5 | palauig
# Processing Record 13 of Set 5 | caucaia
# Processing Record 14 of Set 5 | hamilton
# Processing Record 15 of Set 5 | ixtapa
# Processing Record 16 of Set 5 | devils lake
# Processing Record 17 of Set 5 | srednekolymsk
# Processing Record 18 of Set 5 | sinegorye
# Processing Record 19 of Set 5 | belaya gora
# Processing Record 20 of Set 5 | payo
# Processing Record 21 of Set 5 | kinablangan
# Processing Record 22 of Set 5 | varhaug
# Processing Record 23 of Set 5 | florianopolis
# Processing Record 24 of Set 5 | qaqortoq
# Processing Record 25 of Set 5 | chumphon
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | san patricio
# Processing Record 28 of Set 5 | namibe
# Processing Record 29 of Set 5 | nicoya
# Processing Record 30 of Set 5 | taos
# Processing Record 31 of Set 5 | caborca
# Processing Record 32 of Set 5 | okhotsk
# Processing Record 33 of Set 5 | longyearbyen
# Processing Record 34 of Set 5 | bukoba
# Processing Record 35 of Set 5 | formosa
# Processing Record 36 of Set 5 | kahului
# Processing Record 37 of Set 5 | changying
# Processing Record 38 of Set 5 | altamira
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | broken hill
# Processing Record 41 of Set 5 | leningradskiy
# Processing Record 42 of Set 5 | komsomolskiy
# Processing Record 43 of Set 5 | shestakovo
# Processing Record 44 of Set 5 | diplo
# Processing Record 45 of Set 5 | kamphaeng phet
# Processing Record 46 of Set 5 | cidreira
# Processing Record 47 of Set 5 | riverton
# Processing Record 48 of Set 5 | pangnirtung
# Processing Record 49 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 5 | souris
# Processing Record 1 of Set 6 | maunabo
# Processing Record 2 of Set 6 | nuuk
# Processing Record 3 of Set 6 | torbay
# Processing Record 4 of Set 6 | stuttgart
# Processing Record 5 of Set 6 | skjervoy
# Processing Record 6 of Set 6 | kamaishi
# Processing Record 7 of Set 6 | ostrovnoy
# Processing Record 8 of Set 6 | zhangye
# Processing Record 9 of Set 6 | ampanihy
# Processing Record 10 of Set 6 | khatanga
# Processing Record 11 of Set 6 | chumikan
# Processing Record 12 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 6 | cacequi
# Processing Record 14 of Set 6 | deputatskiy
# Processing Record 15 of Set 6 | laguna
# Processing Record 16 of Set 6 | jasper
# Processing Record 17 of Set 6 | borogontsy
# Processing Record 18 of Set 6 | natal
# Processing Record 19 of Set 6 | mazyr
# Processing Record 20 of Set 6 | humboldt
# Processing Record 21 of Set 6 | nancalabasaan
# City not found. Skipping...
# Processing Record 22 of Set 6 | cookeville
# Processing Record 23 of Set 6 | grand gaube
# Processing Record 24 of Set 6 | hailar
# Processing Record 25 of Set 6 | macapa
# Processing Record 26 of Set 6 | sao joao da barra
# Processing Record 27 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 28 of Set 6 | novosheshminsk
# Processing Record 29 of Set 6 | gushikawa
# Processing Record 30 of Set 6 | mayumba
# Processing Record 31 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 32 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 33 of Set 6 | kadirli
# Processing Record 34 of Set 6 | batemans bay
# Processing Record 35 of Set 6 | shihezi
# Processing Record 36 of Set 6 | qrendi
# Processing Record 37 of Set 6 | changde
# Processing Record 38 of Set 6 | kuito
# Processing Record 39 of Set 6 | kavaratti
# Processing Record 40 of Set 6 | agria
# Processing Record 41 of Set 6 | tura
# Processing Record 42 of Set 6 | ennis
# Processing Record 43 of Set 6 | jalu
# Processing Record 44 of Set 6 | goderich
# Processing Record 45 of Set 6 | saint-philippe
# Processing Record 46 of Set 6 | karaton
# Processing Record 47 of Set 6 | oranjestad
# Processing Record 48 of Set 6 | boyolangu
# Processing Record 49 of Set 6 | walla walla
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 7 | guanica
# Processing Record 4 of Set 7 | santa isabel do rio negro
# Processing Record 5 of Set 7 | magdiwang
# Processing Record 6 of Set 7 | coquimbo
# Processing Record 7 of Set 7 | aksarka
# Processing Record 8 of Set 7 | dingle
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | kheri
# Processing Record 11 of Set 7 | tarakan
# Processing Record 12 of Set 7 | vostok
# Processing Record 13 of Set 7 | moroni
# Processing Record 14 of Set 7 | brae
# Processing Record 15 of Set 7 | nyurba
# Processing Record 16 of Set 7 | oda
# Processing Record 17 of Set 7 | yidu
# Processing Record 18 of Set 7 | krabi
# Processing Record 19 of Set 7 | harper
# Processing Record 20 of Set 7 | caucasia
# Processing Record 21 of Set 7 | te anau
# Processing Record 22 of Set 7 | gat
# Processing Record 23 of Set 7 | mayor pablo lagerenza
# Processing Record 24 of Set 7 | shimoda
# Processing Record 25 of Set 7 | formosa do rio preto
# Processing Record 26 of Set 7 | enshi
# Processing Record 27 of Set 7 | coahuayana
# Processing Record 28 of Set 7 | pevek
# Processing Record 29 of Set 7 | poum
# Processing Record 30 of Set 7 | brigantine
# Processing Record 31 of Set 7 | shieli
# Processing Record 32 of Set 7 | xiongzhou
# Processing Record 33 of Set 7 | trogir
# Processing Record 34 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 7 | vinh
# Processing Record 37 of Set 7 | georgetown
# Processing Record 38 of Set 7 | waddan
# Processing Record 39 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 7 | beyneu
# Processing Record 41 of Set 7 | constitucion
# Processing Record 42 of Set 7 | tolaga bay
# Processing Record 43 of Set 7 | palu
# Processing Record 44 of Set 7 | port hedland
# Processing Record 45 of Set 7 | tete
# Processing Record 46 of Set 7 | ronneby
# Processing Record 47 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 48 of Set 7 | tokur
# Processing Record 49 of Set 7 | socuellamos
# Processing Record 50 of Set 7 | slave lake
# Processing Record 1 of Set 8 | carnarvon
# Processing Record 2 of Set 8 | crewe
# Processing Record 3 of Set 8 | wattegama
# Processing Record 4 of Set 8 | bud
# Processing Record 5 of Set 8 | jaciara
# Processing Record 6 of Set 8 | college
# Processing Record 7 of Set 8 | preobrazheniye
# Processing Record 8 of Set 8 | umm lajj
# Processing Record 9 of Set 8 | bilma
# Processing Record 10 of Set 8 | maningrida
# Processing Record 11 of Set 8 | georgiyevka
# Processing Record 12 of Set 8 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 13 of Set 8 | malindi
# Processing Record 14 of Set 8 | nioro
# Processing Record 15 of Set 8 | chifeng
# Processing Record 16 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 8 | stepnyak
# Processing Record 18 of Set 8 | kaitangata
# Processing Record 19 of Set 8 | burica
# City not found. Skipping...
# Processing Record 20 of Set 8 | tiksi
# Processing Record 21 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 22 of Set 8 | dakar
# Processing Record 23 of Set 8 | narsaq
# Processing Record 24 of Set 8 | forestville
# Processing Record 25 of Set 8 | port augusta
# Processing Record 26 of Set 8 | naze
# Processing Record 27 of Set 8 | beira
# Processing Record 28 of Set 8 | khasan
# Processing Record 29 of Set 8 | faanui
# Processing Record 30 of Set 8 | marau
# Processing Record 31 of Set 8 | chimbote
# Processing Record 32 of Set 8 | cabedelo
# Processing Record 33 of Set 8 | gunnedah
# Processing Record 34 of Set 8 | pitea
# Processing Record 35 of Set 8 | marabba
# Processing Record 36 of Set 8 | davila
# Processing Record 37 of Set 8 | pascagoula
# Processing Record 38 of Set 8 | henties bay
# Processing Record 39 of Set 8 | husavik
# Processing Record 40 of Set 8 | batagay-alyta
# Processing Record 41 of Set 8 | langsa
# Processing Record 42 of Set 8 | mehran
# Processing Record 43 of Set 8 | mana
# Processing Record 44 of Set 8 | brande
# Processing Record 45 of Set 8 | save
# Processing Record 46 of Set 8 | longido
# Processing Record 47 of Set 8 | calderitas
# Processing Record 48 of Set 8 | arman
# Processing Record 49 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 50 of Set 8 | faya
# Processing Record 1 of Set 9 | hovd
# Processing Record 2 of Set 9 | vardo
# Processing Record 3 of Set 9 | paengaroa
# Processing Record 4 of Set 9 | abilene
# Processing Record 5 of Set 9 | howard springs
# Processing Record 6 of Set 9 | iwanai
# Processing Record 7 of Set 9 | berlevag
# Processing Record 8 of Set 9 | uniontown
# Processing Record 9 of Set 9 | plainview
# Processing Record 10 of Set 9 | road town
# Processing Record 11 of Set 9 | piranhas
# Processing Record 12 of Set 9 | takoradi
# Processing Record 13 of Set 9 | tilichiki
# Processing Record 14 of Set 9 | lompoc
# Processing Record 15 of Set 9 | adrar
# Processing Record 16 of Set 9 | odienne
# Processing Record 17 of Set 9 | maniwaki
# Processing Record 18 of Set 9 | magan
# Processing Record 19 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 9 | mnogovershinnyy
# Processing Record 21 of Set 9 | bria
# Processing Record 22 of Set 9 | kendari
# Processing Record 23 of Set 9 | pisco
# Processing Record 24 of Set 9 | leo
# Processing Record 25 of Set 9 | lyuban
# Processing Record 26 of Set 9 | moree
# Processing Record 27 of Set 9 | sungaipenuh
# Processing Record 28 of Set 9 | huntingdon
# Processing Record 29 of Set 9 | comodoro rivadavia
# Processing Record 30 of Set 9 | russkaya polyana
# Processing Record 31 of Set 9 | jacareacanga
# Processing Record 32 of Set 9 | ola
# Processing Record 33 of Set 9 | manitouwadge
# Processing Record 34 of Set 9 | port perry
# Processing Record 35 of Set 9 | axim
# Processing Record 36 of Set 9 | barstow
# Processing Record 37 of Set 9 | bambous virieux
# Processing Record 38 of Set 9 | carroll
# Processing Record 39 of Set 9 | ambatofinandrahana
# Processing Record 40 of Set 9 | salamanca
# Processing Record 41 of Set 9 | iqaluit
# Processing Record 42 of Set 9 | helong
# Processing Record 43 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 9 | richards bay
# Processing Record 45 of Set 9 | dalvik
# Processing Record 46 of Set 9 | yarensk
# Processing Record 47 of Set 9 | pakxan
# Processing Record 48 of Set 9 | ulaanbaatar
# Processing Record 49 of Set 9 | ringebu
# Processing Record 50 of Set 9 | clarksburg
# Processing Record 1 of Set 10 | teya
# Processing Record 2 of Set 10 | rasulabad
# Processing Record 3 of Set 10 | capreol
# Processing Record 4 of Set 10 | luganville
# Processing Record 5 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 10 | sambava
# Processing Record 8 of Set 10 | altea
# Processing Record 9 of Set 10 | zheleznodorozhnyy
# Processing Record 10 of Set 10 | aksha
# Processing Record 11 of Set 10 | maidens
# Processing Record 12 of Set 10 | trelew
# Processing Record 13 of Set 10 | alice springs
# Processing Record 14 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 15 of Set 10 | manokwari
# Processing Record 16 of Set 10 | ranfurly
# Processing Record 17 of Set 10 | hargeysa
# Processing Record 18 of Set 10 | shache
# Processing Record 19 of Set 10 | scarborough
# Processing Record 20 of Set 10 | bose
# Processing Record 21 of Set 10 | tutoia
# Processing Record 22 of Set 10 | mwinilunga
# Processing Record 23 of Set 10 | odweyne
# Processing Record 24 of Set 10 | waipawa
# Processing Record 25 of Set 10 | rotenburg
# Processing Record 26 of Set 10 | general roca
# Processing Record 27 of Set 10 | ouadda
# Processing Record 28 of Set 10 | quinchia
# Processing Record 29 of Set 10 | sendafa
# Processing Record 30 of Set 10 | taltal
# Processing Record 31 of Set 10 | mwanza
# Processing Record 32 of Set 10 | tahoua
# Processing Record 33 of Set 10 | saint-georges
# Processing Record 34 of Set 10 | bathsheba
# Processing Record 35 of Set 10 | bodaybo
# Processing Record 36 of Set 10 | hervey bay
# Processing Record 37 of Set 10 | biak
# Processing Record 38 of Set 10 | perth
# Processing Record 39 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 40 of Set 10 | safaqis
# City not found. Skipping...
# Processing Record 41 of Set 10 | maceio
# Processing Record 42 of Set 10 | norwich
# Processing Record 43 of Set 10 | najran
# Processing Record 44 of Set 10 | thinadhoo
# Processing Record 45 of Set 10 | singkawang
# Processing Record 46 of Set 10 | camopi
# Processing Record 47 of Set 10 | wilhelmshaven
# Processing Record 48 of Set 10 | lukiv
# Processing Record 49 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 10 | northam
# Processing Record 1 of Set 11 | meulaboh
# Processing Record 2 of Set 11 | zakharovo
# Processing Record 3 of Set 11 | tshikapa
# Processing Record 4 of Set 11 | bafra
# Processing Record 5 of Set 11 | inuvik
# Processing Record 6 of Set 11 | manoel urbano
# Processing Record 7 of Set 11 | matara
# Processing Record 8 of Set 11 | marsa matruh
# Processing Record 9 of Set 11 | lorengau
# Processing Record 10 of Set 11 | penzance
# Processing Record 11 of Set 11 | nakasongola
# Processing Record 12 of Set 11 | nisia floresta
# Processing Record 13 of Set 11 | namtsy
# Processing Record 14 of Set 11 | moose factory
# Processing Record 15 of Set 11 | dongsheng
# Processing Record 16 of Set 11 | longview
# Processing Record 17 of Set 11 | bengkulu
# Processing Record 18 of Set 11 | oriximina
# Processing Record 19 of Set 11 | linqu
# Processing Record 20 of Set 11 | cootamundra
# Processing Record 21 of Set 11 | lulea
# Processing Record 22 of Set 11 | gachantiva
# City not found. Skipping...
# Processing Record 23 of Set 11 | radom
# Processing Record 24 of Set 11 | mutoko
# Processing Record 25 of Set 11 | bambanglipuro
# Processing Record 26 of Set 11 | cururupu
# Processing Record 27 of Set 11 | korla
# Processing Record 28 of Set 11 | omsukchan
# Processing Record 29 of Set 11 | mayya
# Processing Record 30 of Set 11 | mtsamboro
# Processing Record 31 of Set 11 | tasiilaq
# Processing Record 32 of Set 11 | san policarpo
# Processing Record 33 of Set 11 | kamina
# Processing Record 34 of Set 11 | villamontes
# Processing Record 35 of Set 11 | lensk
# Processing Record 36 of Set 11 | ozernovskiy
# Processing Record 37 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 11 | christchurch
# Processing Record 39 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 11 | moratuwa
# Processing Record 41 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 42 of Set 11 | dinuba
# Processing Record 43 of Set 11 | mount gambier
# Processing Record 44 of Set 11 | talakan
# Processing Record 45 of Set 11 | bende
# Processing Record 46 of Set 11 | kirakira
# Processing Record 47 of Set 11 | oneonta
# Processing Record 48 of Set 11 | asau
# Processing Record 49 of Set 11 | sattahip
# Processing Record 50 of Set 11 | hov
# Processing Record 1 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 12 | maumere
# Processing Record 3 of Set 12 | mecca
# Processing Record 4 of Set 12 | rovaniemi
# Processing Record 5 of Set 12 | kalmunai
# Processing Record 6 of Set 12 | nanortalik
# Processing Record 7 of Set 12 | carutapera
# Processing Record 8 of Set 12 | baisha
# Processing Record 9 of Set 12 | tevaitoa
# Processing Record 10 of Set 12 | villa bruzual
# Processing Record 11 of Set 12 | ginir
# Processing Record 12 of Set 12 | yulara
# Processing Record 13 of Set 12 | gorontalo
# Processing Record 14 of Set 12 | crailsheim
# Processing Record 15 of Set 12 | dornoch
# Processing Record 16 of Set 12 | beringovskiy
# Processing Record 17 of Set 12 | otanche
# Processing Record 18 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 12 | erie
# Processing Record 20 of Set 12 | palmer
# Processing Record 21 of Set 12 | cuiluan
# Processing Record 22 of Set 12 | mangrol
# Processing Record 23 of Set 12 | vanimo
# Processing Record 24 of Set 12 | lucapa
# Processing Record 25 of Set 12 | dalbandin
# Processing Record 26 of Set 12 | presidente olegario
# Processing Record 27 of Set 12 | san joaquin
# Processing Record 28 of Set 12 | storforshei
# Processing Record 29 of Set 12 | murray bridge
# Processing Record 30 of Set 12 | dickinson
# Processing Record 31 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 32 of Set 12 | san juan
# Processing Record 33 of Set 12 | mintlaw
# Processing Record 34 of Set 12 | abengourou
# Processing Record 35 of Set 12 | gore
# Processing Record 36 of Set 12 | vung tau
# Processing Record 37 of Set 12 | waingapu
# Processing Record 38 of Set 12 | steinbach
# Processing Record 39 of Set 12 | westport
# Processing Record 40 of Set 12 | srikakulam
# Processing Record 41 of Set 12 | kaohsiung
# Processing Record 42 of Set 12 | mount isa
# Processing Record 43 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 12 | vestmannaeyjar
# Processing Record 45 of Set 12 | riyadh
# Processing Record 46 of Set 12 | erzin
# Processing Record 47 of Set 12 | teguldet
# Processing Record 48 of Set 12 | santa lucia
# Processing Record 49 of Set 12 | rabo de peixe
# Processing Record 50 of Set 12 | ha noi
# Processing Record 1 of Set 13 | farafangana
# Processing Record 2 of Set 13 | piacabucu
# Processing Record 3 of Set 13 | myaundzha
# Processing Record 4 of Set 13 | wewak
# Processing Record 5 of Set 13 | songkhla
# Processing Record 6 of Set 13 | altay
# Processing Record 7 of Set 13 | kapit
# Processing Record 8 of Set 13 | yar-sale
# Processing Record 9 of Set 13 | bokoro
# Processing Record 10 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 13 | port hawkesbury
# Processing Record 12 of Set 13 | naliya
# Processing Record 13 of Set 13 | skelleftea
# Processing Record 14 of Set 13 | yuci
# Processing Record 15 of Set 13 | murgab
# Processing Record 16 of Set 13 | cayeli
# Processing Record 17 of Set 13 | pafos
# Processing Record 18 of Set 13 | legnica
# Processing Record 19 of Set 13 | robertsport
# Processing Record 20 of Set 13 | simdega
# Processing Record 21 of Set 13 | acapulco
# Processing Record 22 of Set 13 | sao caetano de odivelas
# Processing Record 23 of Set 13 | kruisfontein
# Processing Record 24 of Set 13 | heihe
# Processing Record 25 of Set 13 | hirara
# Processing Record 26 of Set 13 | iskateley
# Processing Record 27 of Set 13 | tangjiazhuang
# Processing Record 28 of Set 13 | kikwit
# Processing Record 29 of Set 13 | dawlatabad
# Processing Record 30 of Set 13 | novyy urgal
# Processing Record 31 of Set 13 | banes
# Processing Record 32 of Set 13 | beisfjord
# Processing Record 33 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 13 | staunton
# Processing Record 35 of Set 13 | batagay
# Processing Record 36 of Set 13 | angoche
# Processing Record 37 of Set 13 | sao luis de montes belos
# Processing Record 38 of Set 13 | lata
# Processing Record 39 of Set 13 | kutum
# Processing Record 40 of Set 13 | usinsk
# Processing Record 41 of Set 13 | sindand
# City not found. Skipping...
# Processing Record 42 of Set 13 | karoi
# Processing Record 43 of Set 13 | bukama
# Processing Record 44 of Set 13 | montalban
# Processing Record 45 of Set 13 | saint-augustin
# Processing Record 46 of Set 13 | vao
# Processing Record 47 of Set 13 | mazamet
# Processing Record 48 of Set 13 | puerto ayacucho
# Processing Record 49 of Set 13 | benicarlo
# Processing Record 50 of Set 13 | grafton
# Processing Record 1 of Set 14 | dhanaura
# Processing Record 2 of Set 14 | himora
# City not found. Skipping...
# Processing Record 3 of Set 14 | nagpur
# Processing Record 4 of Set 14 | makarov
# Processing Record 5 of Set 14 | garden city
# Processing Record 6 of Set 14 | laranjeiras do sul
# Processing Record 7 of Set 14 | keighley
# Processing Record 8 of Set 14 | dickson
# Processing Record 9 of Set 14 | tongliao
# Processing Record 10 of Set 14 | luau
# Processing Record 11 of Set 14 | sesheke
# Processing Record 12 of Set 14 | touros
# Processing Record 13 of Set 14 | cugir
# Processing Record 14 of Set 14 | catuday
# Processing Record 15 of Set 14 | tigzirt
# Processing Record 16 of Set 14 | taoudenni
# Processing Record 17 of Set 14 | cedar city
# Processing Record 18 of Set 14 | lere
# Processing Record 19 of Set 14 | myrtle beach
# Processing Record 20 of Set 14 | ramhormoz
# Processing Record 21 of Set 14 | ulaangom
# Processing Record 22 of Set 14 | codrington
# Processing Record 23 of Set 14 | porto novo
# Processing Record 24 of Set 14 | payson
# Processing Record 25 of Set 14 | masty
# Processing Record 26 of Set 14 | aklavik
# Processing Record 27 of Set 14 | bodden town
# Processing Record 28 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 14 | bonito
# Processing Record 30 of Set 14 | ternate
# Processing Record 31 of Set 14 | stromness
# Processing Record 32 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 14 | altrincham
# Processing Record 34 of Set 14 | havelock
# Processing Record 35 of Set 14 | rio verde de mato grosso
# Processing Record 36 of Set 14 | nhulunbuy
# Processing Record 37 of Set 14 | panzhihua
# Processing Record 38 of Set 14 | salair
# Processing Record 39 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 40 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 14 | alyangula
# Processing Record 42 of Set 14 | grindavik
# Processing Record 43 of Set 14 | koumac
# Processing Record 44 of Set 14 | asfi
# Processing Record 45 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 14 | olinda
# Processing Record 47 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 14 | knysna
# Processing Record 49 of Set 14 | kosjeric
# Processing Record 50 of Set 14 | bosaso
# Processing Record 1 of Set 15 | kyshtovka
# Processing Record 2 of Set 15 | kozulka
# Processing Record 3 of Set 15 | paamiut
# Processing Record 4 of Set 15 | old road
# City not found. Skipping...
# Processing Record 5 of Set 15 | ferkessedougou
# Processing Record 6 of Set 15 | kamenka
# Processing Record 7 of Set 15 | kaa-khem
# Processing Record 8 of Set 15 | gweta
# Processing Record 9 of Set 15 | maneadero
# Processing Record 10 of Set 15 | rosetta
# Processing Record 11 of Set 15 | qujing
# Processing Record 12 of Set 15 | nola
# Processing Record 13 of Set 15 | dvinskoy
# Processing Record 14 of Set 15 | sinnamary
# Processing Record 15 of Set 15 | doka
# Processing Record 16 of Set 15 | yaring
# Processing Record 17 of Set 15 | weatherford
# Processing Record 18 of Set 15 | tonekabon
# Processing Record 19 of Set 15 | bouar
# Processing Record 20 of Set 15 | bastia
# Processing Record 21 of Set 15 | kurchum
# Processing Record 22 of Set 15 | suntar
# Processing Record 23 of Set 15 | tondela
# Processing Record 24 of Set 15 | lakes entrance
# Processing Record 25 of Set 15 | manga
# Processing Record 26 of Set 15 | fortuna
# Processing Record 27 of Set 15 | energetik
# Processing Record 28 of Set 15 | saint anthony
# Processing Record 29 of Set 15 | khed brahma
# Processing Record 30 of Set 15 | warrington
# Processing Record 31 of Set 15 | jining
# Processing Record 32 of Set 15 | micheweni
# Processing Record 33 of Set 15 | dire dawa
# Processing Record 34 of Set 15 | key west
# Processing Record 35 of Set 15 | kyaukse
# Processing Record 36 of Set 15 | shingu
# Processing Record 37 of Set 15 | kismayo
# Processing Record 38 of Set 15 | vestmanna
# Processing Record 39 of Set 15 | bhitarwar
# Processing Record 40 of Set 15 | chichihualco
# Processing Record 41 of Set 15 | tamandare
# Processing Record 42 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 15 | ugoofaaru
# Processing Record 44 of Set 15 | xining
# Processing Record 45 of Set 15 | smyrna
# Processing Record 46 of Set 15 | zambezi
# Processing Record 47 of Set 15 | uhlove
# Processing Record 48 of Set 15 | merzifon
# Processing Record 49 of Set 15 | riachao das neves
# Processing Record 50 of Set 15 | garowe
# Processing Record 1 of Set 16 | qasigiannguit
# Processing Record 2 of Set 16 | paragominas
# Processing Record 3 of Set 16 | koslan
# Processing Record 4 of Set 16 | bognor regis
# Processing Record 5 of Set 16 | brcko
# Processing Record 6 of Set 16 | taybad
# Processing Record 7 of Set 16 | rock springs
# Processing Record 8 of Set 16 | mahon
# Processing Record 9 of Set 16 | vetluga
# Processing Record 10 of Set 16 | edgewater
# Processing Record 11 of Set 16 | anadyr
# Processing Record 12 of Set 16 | san rafael
# Processing Record 13 of Set 16 | bay saint louis
# Processing Record 14 of Set 16 | finnsnes
# Processing Record 15 of Set 16 | pailon
# Processing Record 16 of Set 16 | river falls
# Processing Record 17 of Set 16 | bay roberts
# Processing Record 18 of Set 16 | bijie
# Processing Record 19 of Set 16 | biguacu
# Processing Record 20 of Set 16 | touba
# Processing Record 21 of Set 16 | todos santos
# Processing Record 22 of Set 16 | derzhavinsk
# Processing Record 23 of Set 16 | tandalti
# Processing Record 24 of Set 16 | sanok
# Processing Record 25 of Set 16 | peniche
# Processing Record 26 of Set 16 | tawkar
# City not found. Skipping...
# Processing Record 27 of Set 16 | aasiaat
# Processing Record 28 of Set 16 | havoysund
# Processing Record 29 of Set 16 | mogadishu
# Processing Record 30 of Set 16 | solnechnyy
# Processing Record 31 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 16 | sicamous
# Processing Record 33 of Set 16 | berdigestyakh
# Processing Record 34 of Set 16 | saint-paul
# Processing Record 35 of Set 16 | avera
# Processing Record 36 of Set 16 | klaksvik
# Processing Record 37 of Set 16 | sabancuy
# Processing Record 38 of Set 16 | kijang
# Processing Record 39 of Set 16 | namatanai
# Processing Record 40 of Set 16 | mokhotlong
# Processing Record 41 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 16 | novosergiyevka
# Processing Record 43 of Set 16 | muscat
# Processing Record 44 of Set 16 | beloha
# Processing Record 45 of Set 16 | tabuk
# Processing Record 46 of Set 16 | coos bay
# Processing Record 47 of Set 16 | les pavillons-sous-bois
# Processing Record 48 of Set 16 | winnemucca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 734

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Camacha  33.0833  -16.3333     77.54        78          40       12.66
# 1  Esperance -33.8667  121.9000     55.24        75          68       30.29
# 2   Zhigansk  66.7697  123.3711     50.43        84          23       11.43
# 3    Itarema  -2.9248  -39.9167     85.44        60          39       20.33
# 4       Mayo  38.8876  -76.5119     94.23        68         100        5.01
# 5    Isangel -19.5500  169.2667     71.28        74          63       14.85
# 6   Saldanha -33.0117   17.9442     64.45        73           5        7.38
# 7   Sobolevo  54.4299   31.8996     69.66        65          67        5.08
# 8       Chuy -33.6971  -53.4616     54.88        74         100       12.88
# 9  Mahebourg -20.4081   57.7000     68.29        94          40        9.22
#
#   Country Current Description                 Date
# 0      PT    scattered clouds  2021-07-26 17:44:15
# 1      AU       broken clouds  2021-07-26 17:44:16
# 2      RU          few clouds  2021-07-26 17:44:16
# 3      BR    scattered clouds  2021-07-26 17:44:17
# 4      US     overcast clouds  2021-07-26 17:44:17
# 5      VU       broken clouds  2021-07-26 17:41:57
# 6      ZA           clear sky  2021-07-26 17:44:18
# 7      RU       broken clouds  2021-07-26 17:44:22
# 8      UY     overcast clouds  2021-07-26 17:44:23
# 9      MU          light rain  2021-07-26 17:44:23

# %%
order = ["City","Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed", "Current Description"]
city_data_df = city_data_df[order]
city_data_df.head(10)
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0    Camacha      PT  2021-07-26 17:44:15  33.0833  -16.3333     77.54
# 1  Esperance      AU  2021-07-26 17:44:16 -33.8667  121.9000     55.24
# 2   Zhigansk      RU  2021-07-26 17:44:16  66.7697  123.3711     50.43
# 3    Itarema      BR  2021-07-26 17:44:17  -2.9248  -39.9167     85.44
# 4       Mayo      US  2021-07-26 17:44:17  38.8876  -76.5119     94.23
# 5    Isangel      VU  2021-07-26 17:41:57 -19.5500  169.2667     71.28
# 6   Saldanha      ZA  2021-07-26 17:44:18 -33.0117   17.9442     64.45
# 7   Sobolevo      RU  2021-07-26 17:44:22  54.4299   31.8996     69.66
# 8       Chuy      UY  2021-07-26 17:44:23 -33.6971  -53.4616     54.88
# 9  Mahebourg      MU  2021-07-26 17:44:23 -20.4081   57.7000     68.29
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        78          40       12.66    scattered clouds
# 1        75          68       30.29       broken clouds
# 2        84          23       11.43          few clouds
# 3        60          39       20.33    scattered clouds
# 4        68         100        5.01     overcast clouds
# 5        74          63       14.85       broken clouds
# 6        73           5        7.38           clear sky
# 7        65          67        5.08       broken clouds
# 8        74         100       12.88     overcast clouds
# 9        94          40        9.22          light rain

# %%
#Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
